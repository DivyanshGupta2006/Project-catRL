# %%
import os
import sys
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import ast
# %matplotlib inline
sns.set_theme()

# %%
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
from src.strategy.environment import Environment
from src.utils import read_file

# %%
norm_data = read_file.read_merged_training_data(True)
norm_data
# Out:
#                      ('open', 'ETH')  ('high', 'ETH')  ('low', 'ETH')  \
# timestamp
# 2020-10-01 00:00:00         1.000000         0.962171        0.986505
# 2020-10-01 01:00:00         0.922741         1.000000        0.971660
# 2020-10-01 02:00:00         1.000000         1.000000        1.000000
# 2020-10-01 03:00:00         1.000000         0.932530        1.000000
# 2020-10-01 04:00:00         0.970954         1.000000        1.000000
# ...                              ...              ...             ...
# 2024-09-29 19:00:00         0.616359         0.535242        0.735184
# 2024-09-29 20:00:00         0.694987         0.694383        0.623045
# 2024-09-29 21:00:00         0.539842         0.566630        0.669531
# 2024-09-29 22:00:00         0.691029         0.642346        0.567746
# 2024-09-29 23:00:00         0.406069         0.390694        0.402512
#
#                      ('close', 'ETH')  ('volume', 'ETH')  ('rsi', 'ETH')  \
# timestamp
# ...

# %%
unnorm_data = read_file.read_merged_training_data(False)
unnorm_data
# Out:
#                      ('open', 'ETH')  ('high', 'ETH')  ('low', 'ETH')  \
# timestamp
# 2020-10-01 00:00:00           359.83           361.27          358.87
# 2020-10-01 01:00:00           359.30           361.53          358.76
# 2020-10-01 02:00:00           361.41           363.72          361.41
# 2020-10-01 03:00:00           362.61           363.16          361.81
# 2020-10-01 04:00:00           362.33           363.98          362.06
# ...                              ...              ...             ...
# 2024-09-29 19:00:00          2663.79          2667.63         2663.10
# 2024-09-29 20:00:00          2666.77          2673.41         2658.01
# 2024-09-29 21:00:00          2660.89          2668.77         2660.12
# 2024-09-29 22:00:00          2666.62          2671.52         2655.50
# 2024-09-29 23:00:00          2655.82          2662.38         2648.00
#
#                      ('close', 'ETH')  ('volume', 'ETH')  ('rsi', 'ETH')  \
# timestamp
# ...

# %%
env = Environment(unnorm_data, 72)
states = env._get_states(norm_data)
states.shape
# Out:
# torch.Size([1, 72, 126])
